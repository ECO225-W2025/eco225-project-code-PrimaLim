# %%
import json
import pandas as pd
import numpy as np

file_path = r"C:\Users\Acer\Downloads\ECO225Project\Code\yelp_academic_dataset_business.json"
# Open the JSON file with the correct encoding
with open(file_path, "r", encoding="utf-8") as data_file:
    business_data = [json.loads(line) for line in data_file]

# Convert to DataFrame
business_df = pd.DataFrame(business_data)
business_df["stars"].mean()
# Out:
# np.float64(3.5967235576603303)

# %%
business_df.dtypes
# Out:
# business_id      object
# name             object
# address          object
# city             object
# state            object
# postal_code      object
# latitude        float64
# longitude       float64
# stars           float64
# review_count      int64
# is_open           int64
# attributes       object
# categories       object
# hours            object
# dtype: object

# %%
business_df.isnull().any(axis=0)
# Out:
# business_id     False
# name            False
# address         False
# city            False
# state           False
# postal_code     False
# latitude        False
# longitude       False
# stars           False
# review_count    False
# is_open         False
# attributes       True
# categories       True
# hours            True
# dtype: bool

# %%
sorted_bus_df = business_df.sort_values(by="state")
sorted_bus_df
# Out:
#                    business_id                          name  \
# 96221   t2Rhq5ubtKYJB1oqWi_pcw                 McBain Camera
# 127395  xv2optDghfbxGDhTSCvxEA         Whitemud World Health
# 30415   823OhurSJe7SKhFvd9u0uQ           Devaney's Irish Pub
# 71646   mY7DKQ6qQYr_V21TWmspOA        Milestones Restaurants
# 71635   73uFR4QuDuH9VD1oehtOQQ   Summerside Pizza and Donair
# ...                        ...                           ...
# 135715  QQXwvLlbMtnAgjY8YKEzuA                  The Moorings
# 144012  g0fYqQRRKmYIfChE4jMLsg             All Service Citgo
# 29606   qbh_Xg-wfgk_qINdyApMag  Valvoline Instant Oil Change
# 10948   kNK3tjrKa6e_Tf9c9WWehA                   Suave Nails
# 98685   IvQs2hhXKZ4NgZhVZ5jjjQ        Pumpernickles Catering
#
#                                address           city state postal_code  \
# 96221              10805 107 Avenue NW       Edmonton    AB     T5H 0W9
# 127395               4219 99 Street NW       Edmonton    AB     T6E 5V7
# ...
